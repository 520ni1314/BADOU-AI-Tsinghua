# %%
# 引入Python包，在jupyter notebook 运行后可以直接输出多个变量 注意大小写
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_path = 'lenna.png'
img = Image.open(image_path).convert('RGB')
img
img.size
num_channel = len(img.split())
num_channel
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x1E8BFD36748>
# (512, 512)
# 3

# %%
def NN_interpolation(src_img, target_w, target_h):
    src_w, src_h = src_img.size
    num_channel = len(src_img.split())
    src_img_n = np.array(list(src_img.getdata())).reshape(src_w, src_h, num_channel)
    target_img = np.zeros((target_w, target_h, num_channel), dtype='uint8')
    for x in range(target_w):
        for y in range(target_w):
            src_x = int(round((x - 0.5) * (src_w / target_w) - 0.5))
            src_y = int(round((y - 0.5) * (src_h / target_h) - 0.5))
            target_img[x, y, :] = src_img_n[src_x, src_y, :]
    return target_img

# %%
target_iamge = NN_interpolation(img, 700, 700)
target_iamge.shape
# target_iamge
image_show = Image.fromarray(target_iamge)
image_show
image_show.save('lanna_nn.png')
# Out:
# (700, 700, 3)
# <PIL.Image.Image image mode=RGB size=700x700 at 0x1E8C1DFBF48>
